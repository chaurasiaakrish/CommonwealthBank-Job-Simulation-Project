# %%
import requests
import pandas as pd
import re
from collections import Counter

# %%
API_KEY = "1570483370211291137-57O1j09eqId36PGrfWNQmHCnTNShEF"
API_KEY_SECRET = "PXpfKdbqveMLz74ZB4GDYrXpRcP5KqT7oZEfVcBRmZDh1"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAMzn7QEAAAAAAr5SPXy9E%2BGrPOVQvRXleVJAXb8%3DbSkeLskg9dfUUJp6YkmQBdMdxxxqa49FN3hRvhqWTZ23jWdZxL"

# %%
import requests

handle = "CommBank"

url = "https://api.twitter.com/2/tweets/search/recent"

params = {
    "query": f"from:{handle}",
    "max_results": 100,
    "tweet.fields": "created_at,public_metrics,lang",
    "expansions": "author_id",
    "user.fields": "username,created_at,public_metrics"
}

headers = {
    "Authorization": "Bearer BearerAAAAAAAAAAAAAAAAAAAAAMzn7QEAAAAAAr5SPXy9E%2BGrPOVQvRXleVJAXb8%3DbSkeLskg9dfUUJp6YkmQBdMdxxxqa49FN3hRvhqWTZ23jWdZxL "
}

response = requests.get(url, headers=headers, params=params)
tweets = response.json().get("data", [])
print(tweets)
print(response.status_code)  # 200
print(response.json())
# Out:
# []
# 401
# {'title': 'Unauthorized', 'type': 'about:blank', 'status': 401, 'detail': 'Unauthorized'}
